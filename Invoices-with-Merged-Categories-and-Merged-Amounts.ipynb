# %%
import pandas as pd

# %%
df = pd.read_excel("8.-Invoices-with-Merged-Categories-and-Merged-Amounts.xlsx")
df
# Out:
#          Order ID                                    Category  \
# 0  CA-2011-167199  Binders | Art | Phones | Fasteners | Paper
# 1  CA-2011-149020                 Office Supplies | Furniture
# 2  CA-2011-131905   Office Supplies | Technology | Technology
# 3  CA-2011-127614              Accessories | Tables | Binders
#
#                                     Amount
# 0  609.98 | 5.48 | 391.98 | 755.96 | 31.12
# 1                             2.98 | 51.94
# 2                   7.2 | 42.0186 | 42.035
# 3                 234.45 | 1256.22 | 17.46

# %%
# def arrange(item):
#     item = item.str.split("|")
#     data = item.explode('item')
#     return data

# %%
# df['Category_'] = df['Category'].apply(arrange)

# %%
df["Category"] = df["Category"].str.split("|")
df["Amount"] = df["Amount"].str.split("|")

# %%
df = df.explode("Category", ignore_index=True).explode("Amount")
df
# Out:
#           Order ID          Category     Amount
# 0   CA-2011-167199          Binders     609.98
# 1   CA-2011-167199          Binders       5.48
# 2   CA-2011-167199          Binders     391.98
# 3   CA-2011-167199          Binders     755.96
# 4   CA-2011-167199          Binders       31.12
# 5   CA-2011-167199              Art     609.98
# 6   CA-2011-167199              Art       5.48
# 7   CA-2011-167199              Art     391.98
# 8   CA-2011-167199              Art     755.96
# 9   CA-2011-167199              Art       31.12
# 10  CA-2011-167199           Phones     609.98
# 11  CA-2011-167199           Phones       5.48
# 12  CA-2011-167199           Phones     391.98
# 13  CA-2011-167199           Phones     755.96
# 14  CA-2011-167199           Phones       31.12
# 15  CA-2011-167199        Fasteners     609.98
# 16  CA-2011-167199        Fasteners       5.48
# 17  CA-2011-167199        Fasteners     391.98
# 18  CA-2011-167199        Fasteners     755.96
# ...
